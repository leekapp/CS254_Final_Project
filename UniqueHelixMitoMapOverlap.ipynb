# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
sns.set(style="white", color_codes=True)

# %% [markdown]
# ### Import of total overlap between Helix mtDB variants and candidate pathogenic variants from MitoMap
# This is the subset of the Helix mtDB bases that also have alleles in MitoMap
#
# **NOTE** although the same base has alleles in both datasets, there may be different alleles in each dataset per base
#
# - These entries need to be merged with the Helix mtDB (or a random sample of it) to add in candidate pathogenic mutations for model training and testing
# - There are 298 unique bases that appear in both the Helix mtDB and the MitoMap databases and 560 alleles are represented in the intersection
# - In the second code chunk below I eliminate most of the Helix mtDB alleles that do not appear in the MitoMap database

# %%
totHelMitoVars = pd.read_csv("/Users/leekapp/Desktop/CS254/Assignments/FinalProject/totHelMitoVars.csv")
totHelMitoVars.tail(20)
# Out:
#       base wildtype   gene                   alleles    mutation annotation  \
# 968  15942        T  MT-TT                 ["T","C"]  transition        NaN
# 969  15944        T  MT-TT                 ["T","C"]  transition        NaN
# 970  15948        A  MT-TT         ["A","AGGACAAAT"]      in-del        NaN
# 971  15948        A  MT-TT                 ["A","G"]  transition        NaN
# 972  15950        G  MT-TT                 ["G","A"]  transition        NaN
# 973  15951        A  MT-TT                 ["A","G"]  transition        NaN
# 974  15952        C  MT-TT                ["C","CA"]      in-del        NaN
# 975  15952        C  MT-TT                 ["C","T"]  transition        NaN
# 976  15952        C  MT-TT                ["CA","C"]      in-del        NaN
# 977  15965        A  MT-TP                 ["A","G"]  transition        NaN
# 978  15986        G  MT-TP                 ["G","A"]  transition        NaN
# 979  15992        A  MT-TP                 ["A","G"]  transition        NaN
# 980  15992        A  MT-TP                 ["A","G"]  transition        NaN
# 981  15995        G  MT-TP                 ["G","A"]  transition        NaN
# 982  15997        T  MT-TP                 ["T","C"]  transition        NaN
# 983  16002        T  MT-TP                 ["T","C"]  transition        NaN
# 984  16015        T  MT-TP                 ["T","C"]  transition        NaN
# 985  16015        T  MT-TP  ["T","TATTCTCTGTTCTTTC"]      in-del        NaN
# 986  16018        T  MT-TP                 ["T","C"]  transition        NaN
# 987  16023        G  MT-TP                 ["G","A"]  transition        NaN
#
#     helix_feature               MM_allele MM_feature homoplasmic  \
# 968     tRNA_gene                 T15942C   tRNA Thr         yes
# 969     tRNA_gene               T15944del   tRNA Thr         yes
# 970     tRNA_gene                 A15948G   tRNA Thr         yes
# 971     tRNA_gene                 A15948G   tRNA Thr         yes
# 972     tRNA_gene                 G15950A   tRNA Thr         yes
# 973     tRNA_gene                 A15951G   tRNA Thr         yes
# 974     tRNA_gene                 C15952T   tRNA Thr         yes
# 975     tRNA_gene                 C15952T   tRNA Thr         yes
# 976     tRNA_gene                 C15952T   tRNA Thr         yes
# 977     tRNA_gene                 A15965G   tRNA Pro         yes
# 978     tRNA_gene                G15986GG   tRNA Pro         yes
# 979     tRNA_gene                 A15992G   tRNA Pro         yes
# 980     tRNA_gene                 A15992T   tRNA Pro         yes
# 981     tRNA_gene                 G15995A   tRNA Pro          no
# 982     tRNA_gene                 T15997C   tRNA Pro          no
# 983     tRNA_gene                 T16002C   tRNA Pro          no
# 984     tRNA_gene                 T16015C   tRNA Pro          no
# 985     tRNA_gene                 T16015C   tRNA Pro         yes
# 986     tRNA_gene  T16018TTCTCTGTTCTTTCAT   tRNA Pro         yes
# 987     tRNA_gene                 G16023A   tRNA Pro          no
#
#     heteroplasmic  counts_hom    AF_hom  counts_het    AF_het pathogenic  \
# 968           yes         467  0.002383           7  0.000036        yes
# 969           yes          12  0.000061           2  0.000010        yes
# 970            no           1  0.000005           0  0.000000        yes
# 971           yes           3  0.000015           4  0.000020        yes
# 972           yes          11  0.000056           2  0.000010        yes
# 973           yes         208  0.001061           8  0.000041        yes
# 974            no           2  0.000010           0  0.000000        yes
# 975           yes           6  0.000031           2  0.000010        yes
# 976            no           6  0.000031           0  0.000000        yes
# 977            no         116  0.000592           0  0.000000        yes
# 978           yes           1  0.000005           7  0.000036        yes
# 979           yes           7  0.000036           2  0.000010        yes
# 980           yes           7  0.000036           2  0.000010        yes
# 981           yes           0  0.000000          11  0.000056        yes
# 982           yes           0  0.000000           2  0.000010        yes
# 983           yes           0  0.000000           1  0.000005        yes
# 984           yes           0  0.000000           3  0.000015        yes
# 985            no           2  0.000010           0  0.000000        yes
# 986            no           2  0.000010           0  0.000000        yes
# 987           yes           0  0.000000           3  0.000015        yes
#
#                                                disease
# 968                           Possibly LVNC-associated
# 969                                                 MM
# 970                   Reported in tic disorder patient
# 971                   Reported in tic disorder patient
# 972  Dopaminergic nerve cell death (PD) / tic disorder
# 973                              LHON / LHON modulator
# 974                   Reported in tic disorder patient
# 975                   Reported in tic disorder patient
# 976                   Reported in tic disorder patient
# 977                 Dopaminergic nerve cell death (PD)
# 978                                     LHON modulator
# 979        Tic disorder patient / hearing loss patient
# 980       Exercise-induced muscle swelling and fatigue
# 981                            Mitochondrial cytopathy
# 982                               Hearing loss patient
# 983                            Mitochondrial cytopathy
# 984                             Mitochondrial myopathy
# 985                             Mitochondrial myopathy
# 986  Dilated cardiomyopathy (15 bp dup), alternate ...
# 987  Migraine +pigmentary retinopathy +deafness +le...

# %% [markdown]
# ### Limiting overlap dataset to unique bases
# The following process limits the overlap database to Helix mtDB alleles that match the MitoMap alleles because most bases have several alleles in the Helix database but only one pathogenic allele for that base exists in MitoMap

# %%
# checking out how to access specific bases of alleles
print(totHelMitoVars['MM_allele'][0]) 
print(totHelMitoVars['MM_allele'][0][-1])
print(totHelMitoVars['alleles'][0])
print(totHelMitoVars['alleles'][0][6])
# Out:
# C-T
# T
# ["C","A"]
# A

# %%
# creating 'first' and 'last' columns to match Helix allele (last base) with last base of MM allele
idx = totHelMitoVars.index
first = np.full(idx.size, 'x')
for i in range(len(idx)):
    first[i] = totHelMitoVars['alleles'][i][-3]
    #first[i] = int(first[i])
first = pd.Series(first)

last = np.full(idx.size, 'x')
for i in range(len(idx)):
    last[i] = totHelMitoVars['MM_allele'][i][-1]
    #first[i] = int(first[i])
last = pd.Series(last)

# %%
# matching base number with alleles
nucleotides = pd.DataFrame({'base' : totHelMitoVars['base'], 'first': first, 'last': last})
nucleotides
# Out:
#       base first last
# 0      114     A    T
# 1      114     G    T
# 2      114     T    T
# 3      114     C    T
# 4      146     A    C
# ..     ...   ...  ...
# 983  16002     C    C
# 984  16015     C    C
# 985  16015     C    C
# 986  16018     C    T
# 987  16023     A    A
#
# [988 rows x 3 columns]

# %%
index = nucleotides.loc[nucleotides['first'] == nucleotides['last']] #gives rows where alleles match by last base of Helix allele
index.index #gives just the value of the row index to use to index the overlap dataframe
# Out:
# Int64Index([  2,   5,   8,   9,  10,  16,  17,  19,  20,  23,
#             ...
#             973, 975, 977, 979, 981, 982, 983, 984, 985, 987],
#            dtype='int64', length=574)

# %% [markdown]
# ### These data still have duplicates for matched MitoMap and Helix mtDB bases

# %%
uniqueOverlaps = totHelMitoVars.iloc[index.index,:]
uniqueOverlaps.head(10)
# Out:
#     base wildtype    gene                 alleles    mutation annotation  \
# 2    114        C  MT-CRb               ["C","T"]  transition        NaN
# 5    146        T  MT-CRb               ["T","C"]  transition        NaN
# 8    150        C  MT-CRb               ["C","T"]  transition        NaN
# 9    185        G  MT-CRb               ["G","A"]  transition        NaN
# 10   185        G  MT-CRb         ["G","A","GAA"]      in-del        NaN
# 16   195        T  MT-CRb           ["T","A","C"]      in-del        NaN
# 17   195        T  MT-CRb               ["T","C"]  transition        NaN
# 19   228        G  MT-CRb               ["G","A"]  transition        NaN
# 20   228        G  MT-CRb  ["G","A","GACATAATAA"]      in-del        NaN
# 23   295        C  MT-CRb               ["C","T"]  transition        NaN
#
#    helix_feature MM_allele MM_feature homoplasmic heteroplasmic  counts_hom  \
# 2     non_coding       C-T  noncoding         yes           yes        1974
# 5     non_coding       T-C  noncoding         yes           yes       25525
# 8     non_coding       C-T  noncoding         yes           yes       19751
# 9     non_coding       G-A  noncoding         yes           yes       10568
# 10    non_coding       G-A  noncoding          no           yes           0
# 16    non_coding       T-C  noncoding          no           yes           0
# 17    non_coding       T-C  noncoding         yes           yes       34496
# 19    non_coding       G-A  noncoding         yes           yes        9673
# 20    non_coding       G-A  noncoding          no           yes           0
# 23    non_coding       C-T  noncoding         yes           yes       15983
#
#       AF_hom  counts_het    AF_het pathogenic  \
# 2   0.010072         101  0.000515        yes
# 5   0.130241         622  0.003174        yes
# 8   0.100779         168  0.000857        yes
# 9   0.053923         317  0.001617        yes
# 10  0.000000           1  0.000005        yes
# 16  0.000000           2  0.000010        yes
# 17  0.176015        1050  0.005358        yes
# 19  0.049356         191  0.000975        yes
# 20  0.000000           1  0.000005        yes
# 23  0.081553           8  0.000041        yes
#
#                                               disease
# 2                                       BD-associated
# 5                            Absence of Endometriosis
# 8   Longevity / Cervical Carcinoma / HPV infection...
# 9                                 Low VO2max response
# 10                                Low VO2max response
# 16                       BD-associated / melanoma pts
# 17                       BD-associated / melanoma pts
# 19                                Low VO2max response
# 20                                Low VO2max response
# 23                                Low VO2max response

# %% [markdown]
# ### Finding the duplicated bases

# %%
dups = uniqueOverlaps[uniqueOverlaps.duplicated(keep=False, subset=['base'])==True]
dups
# Out:
#       base wildtype     gene                   alleles      mutation  \
# 9      185        G   MT-CRb                 ["G","A"]    transition
# 10     185        G   MT-CRb           ["G","A","GAA"]        in-del
# 16     195        T   MT-CRb             ["T","A","C"]        in-del
# 17     195        T   MT-CRb                 ["T","C"]    transition
# 19     228        G   MT-CRb                 ["G","A"]    transition
# 20     228        G   MT-CRb    ["G","A","GACATAATAA"]        in-del
# 38     576        A   MT-CRb                 ["A","G"]    transition
# 40    3308        T   MT-ND1                 ["T","C"]    transition
# 41    3308        T   MT-ND1                 ["T","G"]  transversion
# 176   7445        A   MT-CO1                 ["A","C"]  transversion
# 179   7445        A   MT-CO1                 ["A","G"]    transition
# 266   8993        T  MT-ATP6                 ["T","C"]    transition
# 269   8993        T  MT-ATP6                 ["T","G"]  transversion
# 532    576        A   MT-CRb                 ["A","G"]    transition
# 534    593        T    MT-TF                 ["T","C"]    transition
# 536    593        T    MT-TF                ["T","TC"]        in-del
# 557    745        A  MT-RNR1                ["A","AG"]        in-del
# 559    745        A  MT-RNR1                 ["A","G"]    transition
# 561    792        C  MT-RNR1                ["C","CT"]        in-del
# 562    792        C  MT-RNR1                 ["C","T"]    transition
# 585    961        T  MT-RNR1             ["T","A","G"]        in-del
# 587    961        T  MT-RNR1                 ["T","C"]    transition
# 590    961        T  MT-RNR1                 ["T","C"]    transition
# 593    961        T  MT-RNR1                 ["T","G"]  transversion
# 595    961        T  MT-RNR1                ["T","TC"]        in-del
# 598    961        T  MT-RNR1                ["T","TC"]        in-del
# 599    961        T  MT-RNR1              ["T","TCCC"]        in-del
# 602    961        T  MT-RNR1              ["T","TCCC"]        in-del
# 603    961        T  MT-RNR1  ["T","TCCCCC","TCCCCCC"]        in-del
# 606    961        T  MT-RNR1  ["T","TCCCCC","TCCCCCC"]        in-del
# 620   1192        C  MT-RNR1                 ["C","A"]  transversion
# 623   1192        C  MT-RNR1                 ["C","T"]    transition
# 640   1546        A  MT-RNR1                ["A","AT"]        in-del
# 641   1546        A  MT-RNR1                 ["A","T"]  transversion
# 675   3243        A   MT-TL1                 ["A","G"]    transition
# 678   3243        A   MT-TL1                 ["A","T"]  transversion
# 683   3254        C   MT-TL1                 ["C","A"]  transversion
# 688   3254        C   MT-TL1                 ["C","T"]    transition
# 693   3275        C   MT-TL1                 ["C","A"]  transversion
# 698   3275        C   MT-TL1                 ["C","T"]    transition
# 792   5794        T    MT-TC                 ["T","C"]    transition
# 793   5794        T    MT-TC                 ["T","C"]    transition
# 795   5809        G    MT-TC                 ["G","A"]    transition
# 796   5809        G    MT-TC                ["G","GA"]        in-del
# 809   7445        A   MT-CO1                 ["A","C"]  transversion
# 813   7445        A   MT-CO1                 ["A","G"]    transition
# 817   7445        A   MT-CO1                 ["A","T"]  transversion
# 984  16015        T    MT-TP                 ["T","C"]    transition
# 985  16015        T    MT-TP  ["T","TATTCTCTGTTCTTTC"]        in-del
#
#     annotation        helix_feature MM_allele                 MM_feature  \
# 9          NaN           non_coding       G-A                  noncoding
# 10         NaN           non_coding       G-A                  noncoding
# 16         NaN           non_coding       T-C                  noncoding
# 17         NaN           non_coding       T-C                  noncoding
# 19         NaN           non_coding       G-A                  noncoding
# 20         NaN           non_coding       G-A                  noncoding
# 38         NaN           non_coding       A-G  noncoding MT-TF precursor
# 40           2  protein_coding_gene       T-C                        M1T
# 41           2  protein_coding_gene       T-G                     M1term
# 176          3  protein_coding_gene       A-C                   term514S
# 179          3  protein_coding_gene       A-G                term514term
# 266          2  protein_coding_gene       T-C                      L156P
# 269          2  protein_coding_gene       T-G                      L156R
# 532        NaN           non_coding     A576G  noncoding MT-TF precursor
# 534        NaN            tRNA_gene     T593C                   tRNA Phe
# 536        NaN            tRNA_gene     T593C                   tRNA Phe
# 557        NaN            rRNA_gene     A745G                   12S rRNA
# 559        NaN            rRNA_gene     A745G                   12S rRNA
# 561        NaN            rRNA_gene     C792T                   12S rRNA
# 562        NaN            rRNA_gene     C792T                   12S rRNA
# 585        NaN            rRNA_gene     T961G                   12S rRNA
# 587        NaN            rRNA_gene     T961C                   12S rRNA
# 590        NaN            rRNA_gene    T961TC                   12S rRNA
# 593        NaN            rRNA_gene     T961G                   12S rRNA
# 595        NaN            rRNA_gene     T961C                   12S rRNA
# 598        NaN            rRNA_gene    T961TC                   12S rRNA
# 599        NaN            rRNA_gene     T961C                   12S rRNA
# 602        NaN            rRNA_gene    T961TC                   12S rRNA
# 603        NaN            rRNA_gene     T961C                   12S rRNA
# 606        NaN            rRNA_gene    T961TC                   12S rRNA
# 620        NaN            rRNA_gene    C1192A                   12S rRNA
# 623        NaN            rRNA_gene    C1192T                   12S rRNA
# 640        NaN            rRNA_gene    A1546T                   12S rRNA
# 641        NaN            rRNA_gene    A1546T                   12S rRNA
# 675        NaN            tRNA_gene    A3243G             tRNA Leu (UUR)
# 678        NaN            tRNA_gene    A3243T             tRNA Leu (UUR)
# 683        NaN            tRNA_gene    C3254A             tRNA Leu (UUR)
# 688        NaN            tRNA_gene    C3254T             tRNA Leu (UUR)
# 693        NaN            tRNA_gene    C3275A             tRNA Leu (UUR)
# 698        NaN            tRNA_gene    C3275T             tRNA Leu (UUR)
# 792        NaN            tRNA_gene    T5794C                   tRNA Cys
# 793        NaN            tRNA_gene    T5794C                   tRNA Cys
# 795        NaN            tRNA_gene    G5809A                   tRNA Cys
# 796        NaN            tRNA_gene    G5809A                   tRNA Cys
# 809          3  protein_coding_gene    A7445C   tRNA Ser (UCN) precursor
# 813          3  protein_coding_gene    A7445G   tRNA Ser (UCN) precursor
# 817          3  protein_coding_gene    A7445T   tRNA Ser (UCN) precursor
# 984        NaN            tRNA_gene   T16015C                   tRNA Pro
# 985        NaN            tRNA_gene   T16015C                   tRNA Pro
#
#     homoplasmic heteroplasmic  counts_hom    AF_hom  counts_het    AF_het  \
# 9           yes           yes       10568  0.053923         317  0.001617
# 10           no           yes           0  0.000000           1  0.000005
# 16           no           yes           0  0.000000           2  0.000010
# 17          yes           yes       34496  0.176015        1050  0.005358
# 19          yes           yes        9673  0.049356         191  0.000975
# 20           no           yes           0  0.000000           1  0.000005
# 38          yes           yes          10  0.000051           1  0.000005
# 40          yes           yes        1126  0.005745          26  0.000133
# 41          yes            no          89  0.000454           0  0.000000
# 176         yes            no           1  0.000005           0  0.000000
# 179          no           yes           0  0.000000           6  0.000031
# 266          no           yes           0  0.000000           2  0.000010
# 269          no           yes           0  0.000000           1  0.000005
# 532         yes           yes          10  0.000051           1  0.000005
# 534         yes           yes         480  0.002449          41  0.000209
# 536         yes            no          86  0.000439           0  0.000000
# 557          no           yes           0  0.000000           1  0.000005
# 559         yes           yes         333  0.001699           3  0.000015
# 561         yes            no           7  0.000036           0  0.000000
# 562         yes           yes          11  0.000056           1  0.000005
# 585          no           yes           0  0.000000           1  0.000005
# 587         yes           yes         927  0.004730         139  0.000709
# 590         yes           yes         927  0.004730         139  0.000709
# 593         yes           yes        1702  0.008684           1  0.000005
# 595         yes           yes           5  0.000025           2  0.000010
# 598         yes           yes           5  0.000025           2  0.000010
# 599         yes            no           1  0.000005           0  0.000000
# 602         yes            no           1  0.000005           0  0.000000
# 603          no           yes           0  0.000000           1  0.000005
# 606          no           yes           0  0.000000           1  0.000005
# 620         yes            no           6  0.000031           0  0.000000
# 623         yes           yes          18  0.000092           3  0.000015
# 640         yes            no           9  0.000046           0  0.000000
# 641          no           yes           0  0.000000           1  0.000005
# 675         yes           yes           2  0.000010          49  0.000250
# 678          no           yes           0  0.000000           1  0.000005
# 683         yes           yes          81  0.000413           1  0.000005
# 688         yes           yes          66  0.000337           4  0.000020
# 693         yes            no          20  0.000102           0  0.000000
# 698         yes            no           6  0.000031           0  0.000000
# 792         yes           yes          57  0.000291           4  0.000020
# 793         yes           yes          57  0.000291           4  0.000020
# 795         yes           yes          16  0.000082           8  0.000041
# 796         yes           yes           1  0.000005           1  0.000005
# 809         yes            no           1  0.000005           0  0.000000
# 813          no           yes           0  0.000000           6  0.000031
# 817         yes           yes           4  0.000020           1  0.000005
# 984          no           yes           0  0.000000           3  0.000015
# 985         yes            no           2  0.000010           0  0.000000
#
#     pathogenic                                            disease
# 9          yes                                Low VO2max response
# 10         yes                                Low VO2max response
# 16         yes                       BD-associated / melanoma pts
# 17         yes                       BD-associated / melanoma pts
# 19         yes                                Low VO2max response
# 20         yes                                Low VO2max response
# 38         yes                               Hearing loss patient
# 40         yes  MELAS / DEAF enhancer / hypertension / LVNC / ...
# 41         yes                                Sudden Infant Death
# 176        yes                                               DEAF
# 179        yes                                               SNHL
# 266        yes                NARP / Leigh Disease / MILS / other
# 269        yes                NARP / Leigh Disease / MILS / other
# 532        yes                               Hearing loss patient
# 534        yes                          Nonsyndromic hearing loss
# 536        yes                          Nonsyndromic hearing loss
# 557        yes                                    DEAF-associated
# 559        yes                                    DEAF-associated
# 561        yes            Increased risk of nonsyndromic deafness
# 562        yes            Increased risk of nonsyndromic deafness
# 585        yes                           Possibly DEAF-associated
# 587        yes                     DEAF, possibly LVNC-associated
# 590        yes                                               DEAF
# 593        yes                           Possibly DEAF-associated
# 595        yes                     DEAF, possibly LVNC-associated
# 598        yes                                               DEAF
# 599        yes                     DEAF, possibly LVNC-associated
# 602        yes                                               DEAF
# 603        yes                     DEAF, possibly LVNC-associated
# 606        yes                                               DEAF
# 620        yes                                    DEAF-associated
# 623        yes                                    DEAF-associated
# 640        yes                                               DEAF
# 641        yes                                               DEAF
# 675        yes  MELAS / Leigh Syndrome / DMDF / MIDD / SNHL / ...
# 678        yes                           MM / MELAS / SNHL / CPEO
# 683        yes                         Gestational Diabetes (GDM)
# 688        yes                   CPEO / poss. hypertension factor
# 693        yes                                               LHON
# 698        yes   Metabolic syndrome and polycystic ovary syndrome
# 792        yes                   Reported in tic disorder patient
# 793        yes                               Hearing loss patient
# 795        yes                               Hearing loss patient
# 796        yes                               Hearing loss patient
# 809        yes                                               DEAF
# 813        yes                                               SNHL
# 817        yes                                               SNHL
# 984        yes                             Mitochondrial myopathy
# 985        yes                             Mitochondrial myopathy
